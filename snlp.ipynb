# %%
pip install -r requirements.txt
# Out:
# Collecting nltk>=3.8.1 (from -r requirements.txt (line 1))Note: you may need to restart the kernel to use updated packages.
#
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting spacy>=3.7.2 (from -r requirements.txt (line 2))
#   Downloading spacy-3.8.4-cp311-cp311-win_amd64.whl.metadata (27 kB)
# Collecting numpy>=1.24.0 (from -r requirements.txt (line 3))
#   Downloading numpy-2.2.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting pandas>=2.1.0 (from -r requirements.txt (line 4))
#   Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn>=1.3.0 (from -r requirements.txt (line 5))
#   Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting jupyter>=1.0.0 (from -r requirements.txt (line 6))
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting notebook>=7.0.0 (from -r requirements.txt (line 7))
#   Downloading notebook-7.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting click (from nltk>=3.8.1->-r requirements.txt (line 1))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting joblib (from nltk>=3.8.1->-r requirements.txt (line 1))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk>=3.8.1->-r requirements.txt (line 1))
#   Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk>=3.8.1->-r requirements.txt (line 1))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading murmurhash-1.0.11-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading cymem-2.0.10-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading thinc-8.3.4-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading srsly-2.5.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading pydantic-2.10.5-py3-none-any.whl.metadata (30 kB)
# Collecting jinja2 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in .\.venv\lib\site-packages (from spacy>=3.7.2->-r requirements.txt (line 2)) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv\lib\site-packages (from spacy>=3.7.2->-r requirements.txt (line 2)) (24.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\lib\site-packages (from pandas>=2.1.0->-r requirements.txt (line 4)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=2.1.0->-r requirements.txt (line 4))
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.1.0->-r requirements.txt (line 4))
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn>=1.3.0->-r requirements.txt (line 5))
#   Downloading scipy-1.15.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.3.0->-r requirements.txt (line 5))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting jupyter-console (from jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading nbconvert-7.16.5-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in .\.venv\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 6)) (6.29.5)
# Collecting ipywidgets (from jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting jupyterlab (from jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading jupyterlab-4.3.4-py3-none-any.whl.metadata (16 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tornado>=6.2.0 in .\.venv\lib\site-packages (from notebook>=7.0.0->-r requirements.txt (line 7)) (6.4.2)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in .\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in .\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7)) (5.7.2)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading jupyter_events-0.11.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading pywinpty-2.0.14-cp311-none-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in .\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7)) (26.2.0)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: traitlets>=5.6.0 in .\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7)) (5.14.3)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: comm>=0.1.1 in .\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in .\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in .\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (8.31.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: nest-asyncio in .\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in .\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (6.1.1)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting beautifulsoup4 (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading mistune-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pygments>=2.4.1 in .\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6)) (2.19.1)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.7.2->-r requirements.txt (line 2))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in .\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.7.2->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->-r requirements.txt (line 4)) (1.17.0)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting blis<1.3.0,>=1.2.0 (from thinc<8.4.0,>=8.3.4->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading blis-1.2.0-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from tqdm->nltk>=3.8.1->-r requirements.txt (line 1)) (0.4.6)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading cloudpathlib-0.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in .\.venv\lib\site-packages (from jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 6)) (3.0.48)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: decorator in .\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in .\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (0.19.2)
# Requirement already satisfied: stack_data in .\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (0.6.3)
# Collecting attrs>=22.2.0 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading rpds_py-0.22.3-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in .\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in .\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7)) (308)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading python_json_logger-3.2.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading marisa_trie-1.2.1-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: wcwidth in .\.venv\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 6)) (0.2.13)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 6))
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (0.8.4)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.7.2->-r requirements.txt (line 2))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: executing>=1.2.0 in .\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in .\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pure-eval in .\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r requirements.txt (line 6)) (0.2.3)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 7))
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 19.7 MB/s eta 0:00:00
# Downloading spacy-3.8.4-cp311-cp311-win_amd64.whl (12.2 MB)
#    ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#    ------------------------------- -------- 9.7/12.2 MB 50.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.2/12.2 MB 31.8 MB/s eta 0:00:00
# Downloading numpy-2.2.1-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------------------------------- ------- 10.5/12.9 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 33.7 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------- ----- 10.0/11.6 MB 47.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 33.0 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    -------------------------------- ------- 9.2/11.1 MB 47.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 31.6 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading notebook-7.3.2-py3-none-any.whl (13.2 MB)
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    ------------------------------ --------- 10.0/13.2 MB 47.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.2/13.2 MB 31.8 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.10-cp311-cp311-win_amd64.whl (39 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading jupyterlab-4.3.4-py3-none-any.whl (11.7 MB)
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    ---------------------------------- ----- 10.0/11.7 MB 47.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 30.4 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.11-cp311-cp311-win_amd64.whl (25 kB)
# Downloading nbconvert-7.16.5-py3-none-any.whl (258 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl (122 kB)
# Downloading pydantic-2.10.5-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 27.3 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading scipy-1.15.1-cp311-cp311-win_amd64.whl (43.9 MB)
#    ---------------------------------------- 0.0/43.9 MB ? eta -:--:--
#    -------- ------------------------------- 9.4/43.9 MB 45.2 MB/s eta 0:00:01
#    ------------------ --------------------- 19.9/43.9 MB 46.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 30.9/43.9 MB 49.1 MB/s eta 0:00:01
#    -------------------------------------- - 42.2/43.9 MB 49.7 MB/s eta 0:00:01
#    ---------------------------------------  43.8/43.9 MB 49.7 MB/s eta 0:00:01
#    ---------------------------------------  43.8/43.9 MB 49.7 MB/s eta 0:00:01
#    ---------------------------------------- 43.9/43.9 MB 33.2 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.0-cp311-cp311-win_amd64.whl (632 kB)
#    ---------------------------------------- 0.0/632.6 kB ? eta -:--:--
#    --------------------------------------- 632.6/632.6 kB 24.7 MB/s eta 0:00:00
# Downloading thinc-8.3.4-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 19.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typer-0.15.1-py3-none-any.whl (44 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.8.0-py3-none-any.whl (96 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading babel-2.16.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------  9.4/9.6 MB 48.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 29.8 MB/s eta 0:00:00
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading blis-1.2.0-cp311-cp311-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------------------------------------- - 6.0/6.2 MB 46.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 29.4 MB/s eta 0:00:00
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
# Downloading cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading jupyter_events-0.11.0-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    ---------------------------------------- 5.4/5.4 MB 29.8 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Downloading mistune-3.1.0-py3-none-any.whl (53 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Downloading pywinpty-2.0.14-cp311-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 24.2 MB/s eta 0:00:00
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 26.6 MB/s eta 0:00:00
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading marisa_trie-1.2.1-cp311-cp311-win_amd64.whl (152 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading python_json_logger-3.2.1-py3-none-any.whl (14 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.22.3-cp311-cp311-win_amd64.whl (231 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl (38 kB)
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, pytz, fastjsonschema, cymem, wrapt, widgetsnbextension, websocket-client, webcolors, wasabi, urllib3, uri-template, tzdata, types-python-dateutil, tqdm, tinycss2, threadpoolctl, spacy-loggers, spacy-legacy, soupsieve, sniffio, shellingham, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, regex, pyyaml, pywinpty, python-json-logger, pydantic-core, pycparser, prometheus-client, pandocfilters, overrides, numpy, murmurhash, mistune, mdurl, MarkupSafe, marisa-trie, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, joblib, idna, h11, fqdn, defusedxml, cloudpathlib, click, charset-normalizer, certifi, catalogue, bleach, babel, attrs, async-lru, annotated-types, terminado, srsly, smart-open, scipy, requests, referencing, pydantic, preshed, pandas, nltk, markdown-it-py, language-data, jinja2, httpcore, cffi, blis, beautifulsoup4, arrow, anyio, scikit-learn, rich, langcodes, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, httpx, confection, argon2-cffi-bindings, typer, thinc, jupyter-console, jsonschema, argon2-cffi, weasel, nbformat, spacy, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed MarkupSafe-3.0.2 annotated-types-0.7.0 anyio-4.8.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-24.3.0 babel-2.16.0 beautifulsoup4-4.12.3 bleach-6.2.0 blis-1.2.0 catalogue-2.0.10 certifi-2024.12.14 cffi-1.17.1 charset-normalizer-3.4.1 click-8.1.8 cloudpathlib-0.20.0 confection-0.1.5 cymem-2.0.10 defusedxml-0.7.1 fastjsonschema-2.21.1 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 ipywidgets-8.1.5 isoduration-20.11.0 jinja2-3.1.5 joblib-1.4.2 json5-0.10.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.11.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.4 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 mistune-3.1.0 murmurhash-1.0.11 nbclient-0.10.2 nbconvert-7.16.5 nbformat-5.10.4 nltk-3.9.1 notebook-7.3.2 notebook-shim-0.2.4 numpy-2.2.1 overrides-7.7.0 pandas-2.2.3 pandocfilters-1.5.1 preshed-3.0.9 prometheus-client-0.21.1 pycparser-2.22 pydantic-2.10.5 pydantic-core-2.27.2 python-json-logger-3.2.1 pytz-2024.2 pywinpty-2.0.14 pyyaml-6.0.2 referencing-0.35.1 regex-2024.11.6 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rich-13.9.4 rpds-py-0.22.3 scikit-learn-1.6.1 scipy-1.15.1 send2trash-1.8.3 shellingham-1.5.4 smart-open-7.1.0 sniffio-1.3.1 soupsieve-2.6 spacy-3.8.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.0 terminado-0.18.1 thinc-8.3.4 threadpoolctl-3.5.0 tinycss2-1.4.0 tqdm-4.67.1 typer-0.15.1 types-python-dateutil-2.9.0.20241206 tzdata-2024.2 uri-template-1.3.0 urllib3-2.3.0 wasabi-1.1.3 weasel-0.4.1 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.13 wrapt-1.17.2

# %%
from sklearn.feature_extraction.text import CountVectorizer  
from sklearn.model_selection import train_test_split  
from sklearn.naive_bayes import MultinomialNB  
from sklearn.metrics import accuracy_score

# %%
# Example data  
texts = [  
    "I love this movie",  
    "This film was terrible",  
    "What a great experience",  
    "I hate this!",  
    "Absolutely fantastic!",  
    "Not good at all",  
    "Best day ever",  
    "Worst day ever"  
]  
   
# Labels: 1 for positive, 0 for negative  
labels = [1, 0, 1, 0, 1, 0, 1, 0]

# %%
# Initialize the vectorizer  
vectorizer = CountVectorizer()  
   
# Fit and transform the text data  
X = vectorizer.fit_transform(texts)  
   
# Target labels  
y = labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Initialize the classifier  
clf = MultinomialNB()  
   
# Train the model  
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Predict on the test set  
y_pred = clf.predict(X_test)

# %%
# Calculate accuracy  
accuracy = accuracy_score(y_test, y_pred)  
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 100.00%

# %%
# New examples  
new_texts = [  
    "I really enjoy this!",  
    "This is awful",  
    "What a wonderful day",  
    "I’m so sad about this"  
]  
   
# Convert to numerical data  
new_X = vectorizer.transform(new_texts)  
   
# Make predictions  
new_predictions = clf.predict(new_X)  
   
# Display results  
for text, label in zip(new_texts, new_predictions):  
    sentiment = "Positive" if label == 1 else "Negative"  
    print(f"'{text}' -> {sentiment}")
# Out:
# 'I really enjoy this!' -> Positive
# 'This is awful' -> Positive
# 'What a wonderful day' -> Positive
# 'I’m so sad about this' -> Positive

# %%
# After training your model, save it
import joblib

# Save the model
joblib.dump(clf, 'model.joblib')
# Save the vectorizer
joblib.dump(vectorizer, 'vectorizer.joblib')
# Out:
# ['vectorizer.joblib']
